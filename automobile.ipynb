# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/sameerkhan/Documents/DATA CLEANING/Automobile price data _Raw_(before).csv')

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
'''
1. Check for errors in datasets
2. Replace them with a suitable approach and explain why you opted for that method or technique. 
3. Final report on the dataset before and after cleaning.
4. The final dataset needs to be saved to .csv format. 
'''
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
import re

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.loc[df['drive-wheels']=='4wd','drive-wheels'] = 'fwd'

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df['num-of-doors'].fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-284e5c473ffb> in <module>
# ----> 1 df['num-of-doors'].fillna(method='ffill',value=df['num-of-doors'].mode())
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    4515         downcast=None,
#    4516     ) -> Optional["Series"]:
# -> 4517         return super().fillna(
#    4518             value=value,
#    4519             method=method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    6010         """
#    6011         inplace = validate_bool_kwarg(inplace, "inplace")
# -> 6012         value, method = validate_fillna_kwargs(value, method)
#    6013
#    6014         # set the default here, so functions examining the signaure
#
# ...

# %%
df['stroke'] = pd.to_numeric(df['stroke'], errors = 'coerce')
df[]

# %%
df[['stroke']].mode().iloc[0]
# Out:
# stroke    3.4
# Name: 0, dtype: float64

# %%
df['stroke'].replace(to_replace=np.nan,value=df['stroke'].mode()[0],inplace=True)

# %%
type(df['stroke'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df[['stroke']].isnull().sum()
# Out:
# stroke    0
# dtype: int64

# %%
df.loc[df['fuel-type']=='gas','fuel-type'] = 0
df.loc[df['fuel-type']=='diesel','fuel-type'] = 1

# %%
df.loc[df['num-of-doors']=='two','num-of-doors'] = 2
df.loc[df['num-of-doors']=='four','num-of-doors'] = 4

# %%
df['num-of-doors'].head(52)
# Out:
# 0       2
# 1       2
# 2       2
# 3       4
# 4       4
# 5       2
# 6       4
# 7       4
# 8       4
# 9       2
# 10      2
# 11      4
# 12      2
# 13      4
# 14      4
# 15      4
# 16      2
# 17      4
# 18      2
# 19      2
# 20      4
# 21      2
# 22      2
# 23      2
# 24      4
# 25      4
# 26      4
# 27    NaN
# 28      4
# 29      2
# 30      2
# 31      2
# 32      2
# 33      2
# 34      2
# 35      4
# 36      4
# 37      2
# 38      2
# 39      4
# 40      4
# 41      4
# 42      2
# 43      4
# 44      2
# 45      4
# 46      2
# 47      4
# 48      4
# 49      2
# 50      2
# 51      2
# Name: num-of-doors, dtype: object

# %%
df['stroke'].replace(to_replace='?',value=df['stroke'].mean(),inplace=True)

# %%
df.to_csv('/Users/sameerkhan/Documents/DATA CLEANING/Automobile price data _Raw_modetest.csv')

# %%
#if rear wheel drive then its best car
df.loc[df['drive-wheels']=='rwd',['newcol','newcol2']]=['best','thebest']

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0          3.0                 ?  alfa-romero         0        std
# 1          3.0                 ?  alfa-romero         0        std
# 2          1.0                 ?  alfa-romero         0        std
# 3          2.0               164         audi         0        std
# 4          2.0               164         audi         0        std
# ..         ...               ...          ...       ...        ...
# 200       -1.0                95        volvo         0        std
# 201       -1.0                95        volvo         0      turbo
# 202       -1.0                95        volvo         0        std
# 203       -1.0                95        volvo         1      turbo
# 204       -1.0                95        volvo         0      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0              2  convertible          rwd           front        88.6  ...
# ...

# %%
 df.groupby(['make']).mean().sort_values('engine-size',ascending=False)
# Out:
#                symboling  wheel-base      length      width     height  \
# make
# jaguar          0.000000  109.333333  196.966667  69.933333  51.133333
# mercedes-benz   0.000000  110.925000  195.262500  71.062500  55.725000
# porsche         2.600000   92.280000  170.260000  67.120000  51.100000
# bmw             0.375000  103.162500  184.500000  66.475000  54.825000
# volvo          -1.272727  106.481818  188.800000  67.963636  56.236364
# mercury         1.000000  102.700000  178.400000  68.000000  54.800000
# alfa-romero     2.333333   90.566667  169.600000  64.566667  50.000000
# peugot          0.000000  110.200000  191.136364  68.390909  57.181818
# renault         1.000000   96.100000  179.150000  66.550000  52.850000
# audi            1.285714  102.271429  183.828571  68.714286  54.428571
# nissan          1.000000   95.722222  170.988889  65.088889  53.633333
# saab            2.500000   99.100000  186.600000  66.500000  56.100000
# ...

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0          3.0                 ?  alfa-romero         0        std
# 1          3.0                 ?  alfa-romero         0        std
# 2          1.0                 ?  alfa-romero         0        std
# 3          2.0               164         audi         0        std
# 4          2.0               164         audi         0        std
# ..         ...               ...          ...       ...        ...
# 200       -1.0                95        volvo         0        std
# 201       -1.0                95        volvo         0      turbo
# 202       -1.0                95        volvo         0        std
# 203       -1.0                95        volvo         1      turbo
# 204       -1.0                95        volvo         0      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0              2  convertible          rwd           front        88.6  ...
# ...

# %%
#nan_values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    float64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.shape
# Out:
# (205, 29)

# %%
df['num-of-doors'] = df['num-of-doors'].fillna()

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0          3.0                 ?  alfa-romero         0        std
# 1          3.0                 ?  alfa-romero         0        std
# 2          1.0                 ?  alfa-romero         0        std
# 3          2.0               164         audi         0        std
# 4          2.0               164         audi         0        std
# ..         ...               ...          ...       ...        ...
# 200       -1.0                95        volvo         0        std
# 201       -1.0                95        volvo         0      turbo
# 202       -1.0                95        volvo         0        std
# 203       -1.0                95        volvo         1      turbo
# 204       -1.0                95        volvo         0      turbo
#
#      num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0             2.0  convertible          rwd           front        88.6  ...
# ...

# %%
#check where is null values

df[df['stroke'].isnull()]
# Out:
#     symboling normalized-losses   make fuel-type aspiration  num-of-doors  \
# 55        3.0               150  mazda         0        std           2.0
# 56        3.0               150  mazda         0        std           2.0
# 57        3.0               150  mazda         0        std           2.0
# 58        3.0               150  mazda         0        std           2.0
#
#    body-style drive-wheels engine-location  wheel-base  ...  stroke  \
# 55  hatchback          rwd           front        95.3  ...     NaN
# 56  hatchback          rwd           front        95.3  ...     NaN
# 57  hatchback          rwd           front        95.3  ...     NaN
# 58  hatchback          rwd           front        95.3  ...     NaN
#
#     compression-ratio  horsepower  peak-rpm city-mpg highway-mpg  price  \
# 55                9.4         101      6000       17          23  10945
# 56                9.4         101      6000       17          23  11845
# ...

# %%
df.dropna()
# Out:
# array([ 2.,  4., nan])

# %%
df['stroke'].fillna(df['stroke'].mode(),inplace=True)

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df['newcol'].mode()
# Out:
# 0    1
# dtype: object

# %%
df.to_csv('/Users/sameerkhan/Documents/DATA CLEANING/stroke.csv')

# %%
df['bore'].fillna(df['bore'].mode())
# Out:
# 0      3.47
# 1      3.47
# 2      2.68
# 3      3.19
# 4      3.19
#        ...
# 200    3.78
# 201    3.78
# 202    3.58
# 203    3.01
# 204    3.78
# Name: bore, Length: 205, dtype: object

# %%
df.to_csv('/Users/sameerkhan/Documents/DATA CLEANING/bore1.csv')
